# %%
import os
from langchain.chat_models import init_chat_model

import os

os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6KMqM0SG2GmtaE4MX913XzR6bA4IPc_hYpF20MM9-cmuw"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("about software jobs in 2026 to 2030?")

# %%
print(response.text)
# Out:
# Predicting the exact state of any job market, especially in a rapidly evolving field like software, is challenging. However, we can make informed projections for software jobs between 2026 and 2030 based on current trends and expert analyses.
#
# Here's a breakdown of what you can expect:
#
# **Overall Outlook: Continued Strong Demand, Evolving Skillsets**
#
# The fundamental demand for software professionals is projected to remain **very strong**. Technology is becoming increasingly integrated into every aspect of our lives and businesses, driving a constant need for new software development, maintenance, and innovation.
#
# **Key Trends Shaping the Software Job Market (2026-2030):**
#
# 1.  **Artificial Intelligence (AI) and Machine Learning (ML) Dominance:**
#     *   **High Demand:** AI/ML engineers, data scientists, AI researchers, and MLops engineers will be among the most sought-after professionals.
# ...

# %% [markdown]
# # Langugae translation

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Marathi language"),
    HumanMessage("how are you teams working on langchain with google gemini model?"),
]
model.invoke(messages)
# Out:
# AIMessage(content='"Langchain" आणि "Google Gemini" मॉडेलवर काम करणाऱ्या टीम्स कशा प्रकारे काम करत आहेत?\n\nया प्रश्नाची माहिती अधिक स्पष्ट करण्यासाठी, आपण याबद्दल बोलत आहात का की:\n\n1.  **Langchain (लँगचेन) आणि Google Gemini (गुगल जेमिनी) हे मॉडेल एकत्र कसे काम करतात?**\n    *   यामध्ये Langchain चे तंत्रज्ञान (जसे की प्रॉम्प्ट टेम्पलेट्स, चेन्स, एजंट्स) Gemini मॉडेलला कसे वापरते, याबद्दल माहिती अपेक्षित आहे.\n    *   Gemini मॉडेलची क्षमता Langchain च्या मदतीने कशी वाढवता येते, यावर चर्चा असू शकते.\n\n2.  **Google मधील टीम्स Langchain आणि Gemini मॉडेलवर एकत्र काम करत आहेत का?**\n    *   याचा अर्थ असा की Google च्या अंतर्गत टीम्स Gemini मॉडेल विकसित करत आहेत आणि त्याच वेळी Langchain सारख्या फ्रेमवर्कसोबत त्याचे एकत्रीकरण (integration) कसे करायचे यावर काम करत आहेत.\n\n3.  **इतर कंपन्या किंवा डेव्हलपर (विकासक) Langchain आणि Gemini वापरून काय करत आहेत?**\n    *   यामध्ये विविध ॲप्लिकेशन्स (applications), सेवा किंवा प्रोजेक्ट्स (projects) याबद्दल माहिती असू शकते, जे या तंत्रज्ञानाचा वापर
# ...

# %%
response1 = model.invoke(messages)

# %%
print(response1.text)
# Out:
# Google Gemini मॉडेलवर Langchain सोबत काम करणाऱ्या टीम्स कशा आहेत?
#
# या प्रश्नाचे उत्तर देण्यासाठी, मला काही गोष्टी स्पष्ट कराव्या लागतील.
#
# **Langchain आणि Google Gemini ची सद्यस्थिती:**
#
# *   **Langchain:** हे एक लोकप्रिय ओपन-सोर्स फ्रेमवर्क आहे जे मोठ्या भाषिक मॉडेल्स (LLMs) वापरून ऍप्लिकेशन्स तयार करण्यास मदत करते. हे विविध LLMs, डेटा स्रोत आणि साधनांशी सुसंगत आहे.
# *   **Google Gemini:** हे Google चे सर्वात शक्तिशाली आणि अत्याधुनिक LLM आहे. हे एकाधिक प्रकारच्या डेटावर (मजकूर, प्रतिमा, ऑडिओ, व्हिडिओ) प्रक्रिया करण्यास सक्षम आहे.
#
# **Langchain आणि Gemini चे एकत्रीकरण (Integration):**
#
# Google ने Gemini ला Langchain मध्ये समाकलित करण्यासाठी सक्रियपणे काम केले आहे. याचा अर्थ असा की, Langchain वापरणारे डेव्हलपर आता Gemini मॉडेलचा वापर करून ऍप्लिकेशन्स तयार करू शकतात.
#
# **टीम कशा काम करत आहेत?**
#
# 1.  **Langchain डेव्हलपमेंट टीम:**
#     *   ही टीम Langchain फ्रेमवर्कला सतत अपडेट करत आहे.
# ...

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from hindi into english language"),
    HumanMessage("बहुत अच्छा टीम वर्क कर रहे हो आप लोग"), 
]

model.invoke(messages)
# Out:
# AIMessage(content='You guys are doing a great job with teamwork.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9823-3540-79d3-9299-76d98c754905-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 10, 'total_tokens': 28, 'input_token_details': {'cache_read': 0}})

# %%
response2 = model.invoke(messages)

# %%
print(response2.text)
# Out:
# You are all doing great teamwork.

# %%
model.invoke("Hello")
model.invoke([{"role": "user", "content": "Hello"}])
model.invoke([HumanMessage("Hello")])
# Out:
# AIMessage(content='Hello there! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9823-ac6f-78c1-aee8-66dc12fbfa66-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 10, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# # prompt template

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "odia", "text": "how are you"})
prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}), HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})]

# %%
response3 = model.invoke(prompt)
print(response3.content)
# Out:
# ମୁଁ ଭଲ ଅଛି, ଧନ୍ୟବାଦ। ତୁମେ କେମିତି ଅଛ?
