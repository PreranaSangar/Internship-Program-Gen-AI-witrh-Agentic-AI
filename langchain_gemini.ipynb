# %%
pip install -U langchain-google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-google-genai in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (4.2.4)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-google-genai) (2.8.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-google-genai) (1.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.2)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (48.0.0)
# Requirement already satisfied: certifi in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.8.8)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (6.0.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.2.3)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\admin\AppData\Roaming\Python\Python312\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6KMqM0SG2GmtaE4MX913XzR6bA4IPc_hYpF20MM9-cmuw"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(model="gemini-3.5-flash")

# %%
response = model.invoke("What's the capital of France?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': '...'}}]

# %%
model.invoke("About Generative AI and Agentic AI")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The transition from **Generative AI** to **Agentic AI** represents the next major frontier in artificial intelligence. While Generative AI focused on **creation**, Agentic AI focuses on **action and autonomy**. \n\nHere is a comprehensive breakdown of what these two technologies are, how they differ, and how they work together to reshape the future.\n\n---\n\n### 1. Generative AI (The Content Creator)\nGenerative AI (GenAI) refers to artificial intelligence models designed to generate new content—including text, images, music, code, and video—based on the patterns they learned from training data.\n\n*   **Underlying Technology:** Built on Large Language Models (LLMs) like GPT-4, Claude, and LLaMA, or diffusion models like Midjourney and Stable Diffusion.\n*   **How it Works:** It uses probability to predict the most likely next word, pixel, or note based on the user\'s prompt.\n*   **Key Characteristic:** **Passive/Reactive.** It only acts when prompted by a human. It does one task at a time (e.g., "Write an email," "Draw a cat").\n*   **Popular Examples:** ChatGPT, Google Gemini, Midjourney, DALL-E, GitHub Copilot.\n\n---\n\n### 2. Agentic AI (The Autonomous Doer)\nAgentic AI refers to AI systems (called "agents") designed to act autonomously to achieve specific, complex goals. Instead of just answering a prompt, an Agentic AI system can plan, use external tools, make decisions, and self-correct without constant human intervention.\n\n*   **Underlying Technology:** Uses Generative AI (LLMs) as its "brain" for reasoning, but adds frameworks for planning, memory, and tool integration (like LangChain, AutoGPT, or CrewAI).\n*   **How it Works:** You give it a high-level goal (e.g., "Find the best flight to Paris under $800 and book it"). The agent breaks this goal into sub-tasks, researches websites, compares prices, handles errors, and executes the task.\n*   **Key Characteristics:**\n    *   **Autonomy:** Operates independently once a goal is set.\n    *   **Tool Use:** Can use web browsers, calculators, databases, APIs, and software applications.\n    *   **Planning & Reasoning:** Can break down a complex task, prioritize steps, and change course if something goes wrong (looping/iteration).\n    *   **Memory:** Retains short-term memory (for the current task) and long-term memory (past user preferences).\n*   **Popular Examples:** Devin (the autonomous software engineer), AutoGPT, Rabbit R1, and enterprise tools like Salesforce Agentforce.\n\n---\n\n### Summary Comparison: Generative vs. Agentic\n\n| Feature | Generative AI | Agentic AI |\n| :--- | :--- | :--- |\n| **Primary Goal** | Create content (text, image, code). | Accomplish complex workflows and tasks. |\n| **Human Interaction** | **High.** Requires constant prompting and guidance. | **Low.** Human sets the goal; AI operates independently. |\n| **Workflow** | **Linear.** Prompt $\\rightarrow$ Response. | **Iterative Loop.** Plan $\\rightarrow$ Act $\\rightarrow$ Observe $\\rightarrow$ Reflect. |\n| **Action Capability** | Limited to generating information. | Can interact with software, APIs, databases, and browse the web. |\n| **Handling Failure** | Gives a wrong or "hallucinated" answer; requires user to correct it. | Recognizes errors and tries alternative paths to achieve the goal. |\n\n---\n\n### Real-World Example: Booking a Vacation\n\n*   **Generative AI Approach:** \n    *   *You:* "Give me a 3-day itinerary for Tokyo." \n    *   *GenAI:* Generates a beautiful text itinerary. You must then manually go to Expedia, book flights, book hotels, and buy tickets.\n*   **Agentic AI Approach:** \n    *   *You:* "Book me a 3-day trip to Tokyo under $2,000 next month. Buy the flights, book the hotel, and reserve a table at a sushi restaurant."\n    *   *Agentic AI:* Searches flights, finds one within budget, verifies it fits your Google Calendar, books it, finds a hotel, makes the dinner reservation, and sends you a single conf ...
